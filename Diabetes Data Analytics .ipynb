# %%
import pandas as pd

# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.patches as mpatches

# %%
import numpy

# %%
import itertools

# %%
import scipy.stats

# %%
os.chdir("C:\\Users\\alexi\\Downloads") 
#Set working directory so that Python knows where to find the file

# %%
DiabetesData = pd.read_csv(r'\Users\alexi\Downloads\Diabetes_Dataset.csv')

# %%
DiabetesData
# Out:
#      Data as of  Date_Of_Death_Year  Date_Of_Death_Month     AgeGroup  \
# 0    10/20/2020                2020                    1    <18 years
# 1    10/20/2020                2020                    1    <18 years
# 2    10/20/2020                2020                    1  18-29 years
# 3    10/20/2020                2020                    1  18-29 years
# 4    10/20/2020                2020                    1  30-39 years
# ..          ...                 ...                  ...          ...
# 221  10/20/2020                2020                    9  75-84 years
# 222  10/20/2020                2020                    9    80+ years
# 223  10/20/2020                2020                    9    80+ years
# 224  10/20/2020                2020                    9    85+ years
# 225  10/20/2020                2020                    9    85+ years
#
#             Sex  COVID19  Diabetes.uc  Diabetes.mc  C19PlusDiabetes  \
# ...

# %%
df=pd.DataFrame(DiabetesData)

# %%
df
# Out:
#      Data as of  Date_Of_Death_Year  Date_Of_Death_Month     AgeGroup  \
# 0    10/20/2020                2020                    1    <18 years
# 1    10/20/2020                2020                    1    <18 years
# 2    10/20/2020                2020                    1  18-29 years
# 3    10/20/2020                2020                    1  18-29 years
# 4    10/20/2020                2020                    1  30-39 years
# ..          ...                 ...                  ...          ...
# 221  10/20/2020                2020                    9  75-84 years
# 222  10/20/2020                2020                    9    80+ years
# 223  10/20/2020                2020                    9    80+ years
# 224  10/20/2020                2020                    9    85+ years
# 225  10/20/2020                2020                    9    85+ years
#
#             Sex  COVID19  Diabetes.uc  Diabetes.mc  C19PlusDiabetes  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Data as of', 'Date_Of_Death_Year', 'Date_Of_Death_Month', 'AgeGroup',
#        'Sex', 'COVID19', 'Diabetes.uc', 'Diabetes.mc', 'C19PlusDiabetes',
#        'C19PlusHypertensiveDiseases', 'C19PlusMajorCardiovascularDiseases',
#        'C19PlusHypertensiveDiseasesAndMCVD',
#        'C19PlusChronicLowerRespiratoryDisease', 'C19PlusKidneyDisease',
#        'C19PlusChronicLiverDiseaseAndCirrhosis', 'C19PlusObesity'],
#       dtype='object')

# %%
df=df.drop(columns=['Data as of', 'Date_Of_Death_Year', 'Date_Of_Death_Month', 'Diabetes.uc', 'Diabetes.mc' ])
#removing redundant data

# %%
df
# Out:
#         AgeGroup         Sex  COVID19  C19PlusDiabetes  \
# 0      <18 years  Female (F)        0                0
# 1      <18 years    Male (M)        0                0
# 2    18-29 years  Female (F)        0                0
# 3    18-29 years    Male (M)        0                0
# 4    30-39 years  Female (F)        0                0
# ..           ...         ...      ...              ...
# 221  75-84 years    Male (M)     2525              385
# 222    80+ years  Female (F)     3847              426
# 223    80+ years    Male (M)     3277              394
# 224    85+ years  Female (F)     2778              270
# 225    85+ years    Male (M)     2036              229
#
#      C19PlusHypertensiveDiseases  C19PlusMajorCardiovascularDiseases  \
# 0                              0                                   0
# 1                              0                                   0
# 2                              0                                   0
# ...

# %%
indices_to_drop = [222, 223, 224, 225]
#removing conflicting or redundant age groups

# %%
df
# Out:
#         AgeGroup         Sex  COVID19  C19PlusDiabetes  \
# 0      <18 years  Female (F)        0                0
# 1      <18 years    Male (M)        0                0
# 2    18-29 years  Female (F)        0                0
# 3    18-29 years    Male (M)        0                0
# 4    30-39 years  Female (F)        0                0
# ..           ...         ...      ...              ...
# 221  75-84 years    Male (M)     2525              385
# 222    80+ years  Female (F)     3847              426
# 223    80+ years    Male (M)     3277              394
# 224    85+ years  Female (F)     2778              270
# 225    85+ years    Male (M)     2036              229
#
#      C19PlusHypertensiveDiseases  C19PlusMajorCardiovascularDiseases  \
# 0                              0                                   0
# 1                              0                                   0
# 2                              0                                   0
# ...

# %%
import statistics

# %%
#the next several lines are used to establish data needed for comparing the average mortality for

# %%
df = df.dropna(subset=['COVID19'])
# Drop rows with NaN values in 'COVID19' column

# %%
# Extract Covid19 deaths from df
Covid19_deaths = df['COVID19']

# %%
# Calculate the mean of total Covid19 deaths
mean_Covid19_deaths = statistics.mean(Covid19_deaths)

# %%
# Print the mean Covid19 deaths
print("Mean Covid19 deaths:", mean_Covid19_deaths)
# Out:
# Mean Covid19 deaths: 1710.9557522123894

# %%
print(df.columns)
# Out:
# Index(['AgeGroup', 'Sex', 'COVID19', 'C19PlusDiabetes',
#        'C19PlusHypertensiveDiseases', 'C19PlusMajorCardiovascularDiseases',
#        'C19PlusHypertensiveDiseasesAndMCVD',
#        'C19PlusChronicLowerRespiratoryDisease', 'C19PlusKidneyDisease',
#        'C19PlusChronicLiverDiseaseAndCirrhosis', 'C19PlusObesity'],
#       dtype='object')

# %%
df = df.dropna(subset=['C19PlusDiabetes'])
# Drop rows with NaN values in 'C19PlusDiabetes' column

# %%
# Extract C19PlusDiabetes deaths from df
C19PlusDiabetes_deaths = df['C19PlusDiabetes']

# %%
# Calculate the mean of total C19PlusDiabetes deaths
mean_C19PlusDiabetes_deaths = statistics.mean(C19PlusDiabetes_deaths)

# %%
# Print the mean C19PlusDiabetes deaths
print("Mean Covid19 deaths:", mean_C19PlusDiabetes_deaths)
# Out:
# Mean Covid19 deaths: 280.8008849557522

# %%
df = df.dropna(subset=['C19PlusHypertensiveDiseases'])
# Drop rows with NaN values in 'C19PlusHypertensiveDiseases' column

# %%
# Extract C19PlusHypertensiveDiseases deaths from df
C19PlusHypertensiveDiseases_deaths = df['C19PlusHypertensiveDiseases']

# %%
# Calculate the mean of total C19PlusHypertensiveDiseases deaths
mean_C19PlusHypertensiveDiseases_deaths = statistics.mean(C19PlusHypertensiveDiseases_deaths)

# %%
# Print the mean C19PlusHypertensiveDiseases deaths
print("Mean C19PlusHypertensiveDiseases:", mean_C19PlusHypertensiveDiseases_deaths)
# Out:
# Mean C19PlusHypertensiveDiseases: 373.79646017699116

# %%
df = df.dropna(subset=['C19PlusMajorCardiovascularDiseases'])
# Drop rows with NaN values in 'C19PlusMajorCardiovascularDiseases' column

# %%
# Extract C19PlusMajorCardiovascularDiseases deaths from df
C19PlusMajorCardiovascularDiseases_deaths = df['C19PlusMajorCardiovascularDiseases']

# %%
# Calculate the mean of total C19PlusMajorCardiovascularDiseases' deaths
mean_C19PlusMajorCardiovascularDiseases_deaths = statistics.mean(C19PlusMajorCardiovascularDiseases_deaths)

# %%
# Print the mean C19PlusMajorCardiovascularDiseases deaths
print("Mean C19PlusMajorCardiovascularDiseases:", mean_C19PlusMajorCardiovascularDiseases_deaths)
# Out:
# Mean C19PlusMajorCardiovascularDiseases: 796.712389380531

# %%
df = df.dropna(subset=['C19PlusHypertensiveDiseasesAndMCVD'])
# Drop rows with NaN values in 'C19PlusHypertensiveDiseasesAndMCVD' column

# %%
# Extract 'C19PlusHypertensiveDiseasesAndMCVD' deaths from df
C19PlusHypertensiveDiseasesAndMCVD_deaths = df['C19PlusHypertensiveDiseasesAndMCVD']

# %%
# Calculate the mean of total C19PlusHypertensiveDiseasesAndMCVD deaths
mean_C19PlusHypertensiveDiseasesAndMCVD_deaths = statistics.mean(C19PlusHypertensiveDiseasesAndMCVD_deaths)

# %%
# Print the mean C19PlusHypertensiveDiseasesAndMCVD deaths
print("Mean C19PlusHypertensiveDiseasesAndMCVDs:", mean_C19PlusHypertensiveDiseasesAndMCVD_deaths)
# Out:
# Mean C19PlusHypertensiveDiseasesAndMCVDs: 796.712389380531

# %%
df = df.dropna(subset=['C19PlusChronicLowerRespiratoryDisease'])
# Drop rows with NaN values in 'C19PlusChronicLowerRespiratoryDisease' column

# %%
# Extract 'C19PlusChronicLowerRespiratoryDisease' deaths from df
C19PlusChronicLowerRespiratoryDisease_deaths = df['C19PlusChronicLowerRespiratoryDisease']

# %%
# Calculate the mean of total C19PlusChronicLowerRespiratoryDisease deaths
mean_C19PlusChronicLowerRespiratoryDisease_deaths = statistics.mean(C19PlusChronicLowerRespiratoryDisease_deaths)

# %%
# Print the mean C19PlusChronicLowerRespiratoryDisease deaths
print("Mean C19PlusChronicLowerRespiratoryDisease:", mean_C19PlusChronicLowerRespiratoryDisease_deaths)
# Out:
# Mean C19PlusChronicLowerRespiratoryDisease: 146.95575221238937

# %%
df = df.dropna(subset=['C19PlusKidneyDisease'])
# Drop rows with NaN values in 'C19PlusKidneyDisease' column

# %%
# Extract 'C19PlusKidneyDisease' deaths from df
C19PlusKidneyDisease_deaths = df['C19PlusKidneyDisease']

# %%
# Calculate the mean of total C19PlusKidneyDiseasedeaths
mean_C19PlusKidneyDisease_deaths = statistics.mean(C19PlusKidneyDisease_deaths)

# %%
# Print the mean C19PlusKidneyDisease deaths
print("Mean C19PlusKidneyDisease:", mean_C19PlusKidneyDisease_deaths)
# Out:
# Mean C19PlusKidneyDisease: 150.06637168141592

# %%
df = df.dropna(subset=['C19PlusChronicLiverDiseaseAndCirrhosis'])
# Drop rows with NaN values in 'C19PlusChronicLiverDiseaseAndCirrhosis' column

# %%
# Extract 'C19PlusChronicLiverDiseaseAndCirrhosis' deaths from df
C19PlusChronicLiverDiseaseAndCirrhosis_deaths = df['C19PlusChronicLiverDiseaseAndCirrhosis']

# %%
# Calculate the mean of total C19PlusChronicLiverDiseaseAndCirrhosis
mean_C19PlusChronicLiverDiseaseAndCirrhosis_deaths = statistics.mean(C19PlusChronicLiverDiseaseAndCirrhosis_deaths)

# %%
# Print the mean C19PlusChronicLiverDiseaseAndCirrhosis deaths
print("Mean C19PlusKidneyDiseaseC19PlusChronicLiverDiseaseAndCirrhosis:", mean_C19PlusChronicLiverDiseaseAndCirrhosis_deaths)
# Out:
# Mean C19PlusKidneyDiseaseC19PlusChronicLiverDiseaseAndCirrhosis: 13.920353982300885

# %%
df = df.dropna(subset=['C19PlusObesity'])
# Drop rows with NaN values in 'C19PlusObesity' column

# %%
# Extract 'C19PlusObesity' deaths from df
C19PlusObesity_deaths = df['C19PlusObesity']

# %%
# Calculate the mean of total C19PlusObesity
mean_C19PlusObesity_deaths = statistics.mean(C19PlusObesity_deaths)

# %%
# Print the mean C19PlusObesity deaths
print("Mean C19PlusObesity:", mean_C19PlusObesity_deaths)
# Out:
# Mean C19PlusObesity: 58.73893805309734

# %%
import matplotlib.pyplot as plt

# %%
# Mean mortality rates for different comorbidities
mean_values = {
    'C19PlusDiabetes': 279.9189189189189,
    'C19PlusHypertensiveDiseases': 370.14414414414415,
    'C19PlusMajorCardiovascularDiseases': 785.5945945945946,
    'C19PlusHypertensiveDiseasesAndMCVD': 785.5945945945946,
    'C19PlusChronicLowerRespiratoryDisease': 144.81981981981983,
    'C19PlusKidneyDisease': 148.47297297297297,
    'C19PlusChronicLiverDiseaseAndCirrhosis': 14.085585585585585,
    'C19PlusObesity': 59.4954954954955
}

# %%
# Custom colors for the pie chart
colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightskyblue', 'lightpink', 'lightyellow', 'lightgrey', 'lavender']

# Create a pie chart with custom colors
plt.figure(figsize=(8, 8))
patches = plt.pie(mean_values.values(), labels=None, autopct='%1.1f%%', startangle=140, colors=colors)

# Create legend
legend_patches = [mpatches.Patch(color=colors[i], label=comorbidity) for i, comorbidity in enumerate(mean_values.keys())]
plt.legend(handles=legend_patches, loc=(1.05, 0.5))

plt.title('Mean Mortality Rates for Different Comorbidities Associated with COVID-19')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
#build a correlation matrix

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
numeric_df = df.drop(columns=['AgeGroup', 'Sex'])

# %%
# Compute correlation matrix
correlation_matrix = numeric_df.corr()

# %%
# Plot correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
#Building difference of means

# %%
# Calculate difference of means for all pairs of comorbidities
differences = {}
for pair in itertools.combinations(mean_values.keys(), 2):
    mean1 = mean_values[pair[0]]
    mean2 = mean_values[pair[1]]
    difference = mean1 - mean2
    differences[pair] = difference

# %%
# Calculate difference of means for all pairs of comorbidities
differences = {}
for pair in itertools.combinations(mean_values.keys(), 2):
    mean1 = mean_values[pair[0]]
    mean2 = mean_values[pair[1]]
    difference = mean1 - mean2
    differences[pair] = difference

# %%
difference
# Out:
# -45.40990990990991

# %%
# Print the differences of means
for pair, difference in differences.items():
    print(f"Difference of means between {pair[0]} and {pair[1]}: {difference}")
# Out:
# Difference of means between C19PlusDiabetes and C19PlusHypertensiveDiseases: -90.22522522522524
# Difference of means between C19PlusDiabetes and C19PlusMajorCardiovascularDiseases: -505.6756756756757
# Difference of means between C19PlusDiabetes and C19PlusHypertensiveDiseasesAndMCVD: -505.6756756756757
# Difference of means between C19PlusDiabetes and C19PlusChronicLowerRespiratoryDisease: 135.09909909909908
# Difference of means between C19PlusDiabetes and C19PlusKidneyDisease: 131.44594594594594
# Difference of means between C19PlusDiabetes and C19PlusChronicLiverDiseaseAndCirrhosis: 265.8333333333333
# Difference of means between C19PlusDiabetes and C19PlusObesity: 220.4234234234234
# Difference of means between C19PlusHypertensiveDiseases and C19PlusMajorCardiovascularDiseases: -415.45045045045043
# Difference of means between C19PlusHypertensiveDiseases and C19PlusHypertensiveDiseasesAndMCVD: -415.45045045045043
# ...

# %%
#now validate the results of the difference of means with an ANOVA test

# %%
from scipy.stats import f_oneway
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
# Melt the DataFrame to long format, which statsmodels formulas require
df_long = pd.melt(df, var_name='conditions', value_name='values')

# Verify that 'values' column contains only numeric data because you have dirty data 
if not pd.api.types.is_numeric_dtype(df_long['values']):
    df_long['values'] = pd.to_numeric(df_long['values'], errors='coerce')
    
# Check for and handle any NaN values that could cause issues in fitting the model
df_long = df_long.dropna(subset=['values'])    

# Fit the model
model = ols('values ~ C(conditions)', data=df_long).fit()

# Perform the ANOVA
anova_results = sm.stats.anova_lm(model, typ=2)

# Print the ANOVA table
print("ANOVA Table:")
print(anova_results)

# Check for significant differences
if anova_results['PR(>F)'][0] < 0.05:
    print("\nThere are significant differences between the groups.")
    # Conduct post-hoc analysis with Tukey's HSD test
    post_hoc = pairwise_tukeyhsd(endog=df_long['values'], groups=df_long['conditions'], alpha=0.05)
    print("\nPost-Hoc (Tukey's HSD) Results:")
    print(post_hoc)
else:
    print("\nNo significant differences were found between the groups.")
# Out:
# ANOVA Table:
#                      sum_sq      df          F        PR(>F)
# C(conditions)  5.381698e+08     8.0  61.638959  1.942775e-90
# Residual       2.210035e+09  2025.0        NaN           NaN
#
# There are significant differences between the groups.
#
# Post-Hoc (Tukey's HSD) Results:
#                                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#                 group1                                 group2                 meandiff p-adj    lower      upper   reject
# -------------------------------------------------------------------------------------------------------------------------
# C19PlusChronicLiverDiseaseAndCirrhosis C19PlusChronicLowerRespiratoryDisease  133.0354 0.9147  -172.1225  438.1933  False
# C19PlusChronicLiverDiseaseAndCirrhosis                       C19PlusDiabetes  266.8805 0.1428   -38.2774  572.0385  False
# ...
